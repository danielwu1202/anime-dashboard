# %%
import gensim
import pandas as pd
from topic_modeling import preprocess
from topic_modeling import LDA
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
action_anime_data = pd.read_csv('./genres/TV_Action.csv')
action_anime_data.head()
# Out:
#       ID                      Title    Japanese             English  \
# 0  39634                Boy General        소년장수         Boy General
# 1  31700                 Xiao Taiji         小太極          Taichi Kid
# 2  10194  Bada-ui Jeonseol Jangbogo  바다의 전설 장보고  The Legend of Blue
# 3  43868                 Baiyu Tang         白玉堂             Unknown
# 4   8999           Origami Warriors        摺紙戰士             Unknown
#
#                                             Synopsis Type  Episodes  \
# 0  The brave young warrior Seo-Me defeats the Seo...   TV      50.0
# 1                                            Unknown   TV      14.0
# 2  In a not too distant future, the government se...   TV      26.0
# 3                                            Unknown   TV      52.0
# 4  Wang Ji-Cheol and his four friends are strong ...   TV      52.0
#
#             Status Start_Aired      End_Aired  ... Demographics  \
# 0  Finished Airing        1982           1997  ...      Unknown
# ...

# %%
word_no_stopword = preprocess.LDA_preprocess_pipeline(action_anime_data, 'NN', 'NNS')

# %%
coherence_score, lda_model = LDA.make_LDA(word_no_stopword, 1, 15, 1)
# Out:
# 100%|██████████| 14/14 [03:44<00:00, 16.00s/it]

# %%
from pprint import pprint

# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
print(coherence_score)
# Out:
# [(0,
#   '0.045*"defeat" + 0.026*"blood" + 0.023*"princess" + 0.020*"matter" + '
#   '0.020*"unit" + 0.018*"club" + 0.018*"car" + 0.015*"relationship" + '
#   '0.014*"baseball" + 0.014*"mage"'),
#  (1,
#   '0.084*"kenshin" + 0.058*"dojo" + 0.056*"revolutionary" + 0.028*"battousai" '
#   '+ 0.028*"uprising" + 0.028*"kaoru" + 0.028*"kamiya" + 0.028*"himura" + '
#   '0.028*"hitokiri" + 0.028*"guilt"'),
#  (2,
#   '0.049*"year" + 0.025*"power" + 0.024*"friend" + 0.019*"team" + '
#   '0.018*"rewrite" + 0.017*"battle" + 0.017*"earth" + 0.014*"member" + '
#   '0.013*"force" + 0.013*"god"'),
#  (3,
#   '0.071*"season" + 0.048*"door" + 0.040*"game" + 0.027*"string" + '
#   '0.025*"artifact" + 0.023*"color" + 0.022*"saihate" + 0.022*"hoard" + '
#   '0.018*"heart" + 0.016*"player"'),
#  (4,
#   '0.039*"mission" + 0.032*"war" + 0.023*"era" + 0.021*"time" + '
#   '0.020*"country" + 0.019*"peace" + 0.016*"story" + 0.014*"people" + '
#   '0.012*"kingdom" + 0.012*"street"'),
#  (5,
# ...
